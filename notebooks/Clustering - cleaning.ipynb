# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
gdf_delitos = gpd.read_file("../output/tweets-delitos-localizados.geojson")

# %%
df = gdf_delitos.drop(columns=['geometry', 'Unnamed: 0', "index_right", "stroke", "stroke-width", "stroke-opacity", "fill", "fill-opacity", "Description"])  # Elimina la columna de geometría

# %%
df.head()
# Out:
#   DisplayName    UserName                 Timestamp  \
# 0   Segura EP  @segura_ep 2023-09-01 03:20:23+00:00
# 1   Segura EP  @segura_ep 2023-08-24 22:08:45+00:00
# 2   Segura EP  @segura_ep 2023-08-22 05:37:57+00:00
# 3   Segura EP  @segura_ep 2023-07-30 06:50:26+00:00
# 4   Segura EP  @segura_ep 2023-07-22 00:29:11+00:00
#
#                                              Content  Comments  Likes  \
# 0  Desde las cámaras de videovigilancia observamo...       0.0    2.0
# 1  #Alerta | Desde las cámaras de videovigilancia...       0.0    3.0
# 2  Cámaras de videovigilancia monitorean el accid...       0.0    3.0
# 3  #Alerta | Desde las cámaras de videovigilancia...       0.0    2.0
# 4  Cámaras de videovigilancia captan el accidente...       0.0    1.0
#
#    Retweets  Interactions  Delito              Coordenadas  latitude  \
# 0       8.0        2314.0       1  -2.1384511, -79.8913772 -2.138451
# 1       7.0         840.0       1  -2.1269033, -79.9000788 -2.126903
# 2      17.0        2266.0       1  -2.1329058, -79.8899186 -2.132906
# 3      18.0        1490.0       1  -2.1413962, -79.8887857 -2.141396
# 4       1.0        1240.0       1  -2.1329058, -79.8899186 -2.132906
#
#    longitude    Name   Zona
# 0 -79.891377  Sauces  Norte
# 1 -79.900079  Sauces  Norte
# 2 -79.889919  Sauces  Norte
# 3 -79.888786  Sauces  Norte
# 4 -79.889919  Sauces  Norte

# %%
df["Date"] = df["Timestamp"].dt.date

# %%
df["Time"] = df["Timestamp"].dt.time

# %%
df.drop(columns="Timestamp", inplace=True)

# %%
df
# Out:
#     DisplayName    UserName  \
# 0     Segura EP  @segura_ep
# 1     Segura EP  @segura_ep
# 2     Segura EP  @segura_ep
# 3     Segura EP  @segura_ep
# 4     Segura EP  @segura_ep
# ..          ...         ...
# 602         NaN         NaN
# 603         NaN         NaN
# 604         NaN         NaN
# 605         NaN         NaN
# 606         NaN         NaN
#
#                                                Content  Comments  Likes  \
# 0    Desde las cámaras de videovigilancia observamo...       0.0    2.0
# 1    #Alerta | Desde las cámaras de videovigilancia...       0.0    3.0
# 2    Cámaras de videovigilancia monitorean el accid...       0.0    3.0
# 3    #Alerta | Desde las cámaras de videovigilancia...       0.0    2.0
# 4    Cámaras de videovigilancia captan el accidente...       0.0    1.0
# ..                                                 ...       ...    ...
# 602  En el sector de la Huancavilca Sur , delincuen...       0.0    0.0
# 603  Solo en Guayaquil: Delincuente fingió conocer ...       0.0    0.0
# 604  #Guayaquil #Delincuencia Intento de Robo se re...       0.0    0.0
# 605        Roban a un estudiante en el cerro Santa Ana       0.0    0.0
# 606  Después de una persecución, un grupo de delinc...       0.0    0.0
#
#      Retweets  Interactions  Delito                     Coordenadas  latitude  \
# 0         8.0        2314.0       1         -2.1384511, -79.8913772 -2.138451
# 1         7.0         840.0       1         -2.1269033, -79.9000788 -2.126903
# 2        17.0        2266.0       1         -2.1329058, -79.8899186 -2.132906
# 3        18.0        1490.0       1         -2.1413962, -79.8887857 -2.141396
# 4         1.0        1240.0       1         -2.1329058, -79.8899186 -2.132906
# ..        ...           ...     ...                             ...       ...
# 602       0.0           0.0       1         -2.2349311, -79.9002713 -2.234931
# 603       0.0           0.0       1  -2.2338739, -79.90368699999999 -2.233874
# 604       0.0           0.0       1         -2.0646512, -79.8926809 -2.064651
# 605       0.0           0.0       1         -2.1821129, -79.8755336 -2.182113
# 606       0.0           0.0       1          -2.1534532, -79.887782 -2.153453
#
#      longitude                     Name    Zona        Date      Time
# 0   -79.891377                   Sauces   Norte  2023-09-01  03:20:23
# 1   -79.900079                   Sauces   Norte  2023-08-24  22:08:45
# 2   -79.889919                   Sauces   Norte  2023-08-22  05:37:57
# 3   -79.888786                   Sauces   Norte  2023-07-30  06:50:26
# 4   -79.889919                   Sauces   Norte  2023-07-22  00:29:11
# ..         ...                      ...     ...         ...       ...
# 602 -79.900271          Huancavilca Sur     Sur  2022-04-16  15:40:46
# 603 -79.903687          Huancavilca Sur     Sur  2023-05-04  11:00:00
# 604 -79.892681             Mucho Lote 2   Norte  2021-11-29  13:25:00
# 605 -79.875534                Las Peñas  Centro  2022-03-14  19:23:46
# 606 -79.887782  Ciudadela Simon Bolivar   Norte  2023-04-29  11:12:00
#
# [607 rows x 15 columns]

# %%
df.drop_duplicates(subset=['Content'], inplace=True)

# %%
df.reset_index(drop= True, inplace = True)

# %%
keyword_dict = {
    'Robo': ['robo', 'hurto', 'atraco', 'saqueo', 'apropiacion indebida','asalt','roba'],
    'Agresión': ['agresion', 'pelea', 'violencia', 'golpiza', 'ataque', 'maltrato','balacera','hirio','heri','golp','bala','puñetes', 'dispar', 'paliza', 'balead','gresion' ],
    'Drogas': ['drogas', 'narcotrafico', 'estupefacientes', 'consumo', 'venta'],
    'Homicidio': ['homicidio', 'muert', 'asesin', 'sicariato','masacre','desmembr', 'decapit', 'acribill', 'descuarti', 'femicidio', 'mata', 'mato', ],
    'Accidente Vehicular': ['atropella','accidente', 'colision', 'choque', 'atropello', 'vehiculo', 'conductor','siniestro de transito','volco','volcamiento','volcado'],
    'Secuestro': ['secuestr', 'retenido', 'plagio', 'liberacion', 'rescate', 'encerr'],
    'Fraude': ['fraude', 'estafa', 'engaño', 'falsificacion', 'delito financiero', 'extorsionadores'],
    'Extorsión':['vacuna', 'extorsion'],
    'Incendio': ['incendio', 'fuego', 'quemar', 'combustion', 'siniestro'],
    'Vandalismo': ['vandalismo', 'destrozo', 'daños', 'destruccion', 'pintadas','explosivo','bomba','relaciones sexuales', 'dinamita'],
    'Violación': ['violacion', 'agresion sexual', 'abuso sexual', 'abusar', 'violador'],
    # Agrega más tipos de delitos y palabras clave según sea necesario
}

# %%
def remove_tildes(texto):
    tildes_dict = {
        'á': 'a',
        'é': 'e',
        'í': 'i',
        'ó': 'o',
        'ú': 'u',
        'Á': 'A',
        'É': 'E',
        'Í': 'I',
        'Ó': 'O',
        'Ú': 'U',
    }

    texto_sin_tildes = ''.join(tildes_dict.get(caracter, caracter) for caracter in texto)
    return texto_sin_tildes

def categorizar_delito(tweet):
    contenido = remove_tildes(tweet['Content'].lower())
    
    # Buscar palabras clave en el contenido del tweet
    for delito, palabras_clave in keyword_dict.items():
        for palabra in palabras_clave:
            if palabra in contenido:
                return delito
    
    # Si no se encuentra ninguna coincidencia, asignar 'Otro'
    return 'Otro'

# %%
df['TipoDelito'] = df.apply(categorizar_delito, axis=1)

# %%
df.loc[df["TipoDelito"]=="Otro",:].shape
# Out:
# (37, 16)

# %%
def cambiar_Tipo_Delito(indices, tipo_delito):
    for indice in indices:
        df.at[(indice-2),'TipoDelito'] = tipo_delito

# %%
cambiar_Tipo_Delito([47,144,516], 'Robo')
cambiar_Tipo_Delito([305,352,462], 'Homicidio')
cambiar_Tipo_Delito([189,265,563,564,565], 'Vandalismo')
cambiar_Tipo_Delito([526], 'Extorsión')

# %%
df = df.loc[df["TipoDelito"]!="Otro",:]

# %%
df_interactions = df.dropna(subset="DisplayName")

# %%
df.to_csv("../output/tweets_con_tipo_delito.csv", index=False)

# %%
interXdelito = df_interactions.groupby("TipoDelito")["Comments", "Likes", "Retweets", "Interactions"].sum().reset_index()
# Out:
# C:\Users\lo206\AppData\Local\Temp\ipykernel_2704\724675455.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   interXdelito = df_interactions.groupby("TipoDelito")["Comments", "Likes", "Retweets", "Interactions"].sum().reset_index()

# %%
interXdelito
# Out:
#             TipoDelito  Comments      Likes  Retweets  Interactions
# 0  Accidente Vehicular     734.0   3293.000   11008.0    15437151.0
# 1             Agresión    1368.0   6824.000   22000.0    17420262.0
# 2            Extorsión     502.0     58.356    1901.0     1386000.0
# 3               Fraude      19.0    180.000     332.0      359555.0
# 4            Homicidio     731.0   5845.000   16153.0    33585276.0
# 5             Incendio       5.0     84.000     303.0     2299527.0
# 6                 Robo    5769.0  22932.004   78534.0    78268948.0
# 7            Secuestro       0.0     60.000     176.0      134000.0
# 8           Vandalismo     354.0    866.000    2717.0     4213323.0

# %%
interXdelito.to_csv("../output/intercciones-por-delito.csv", index=False)

# %%
barrioXdelito = pd.pivot_table(df, values = 'Likes', index=['Name'], columns=['TipoDelito'], aggfunc="count").reset_index()

# %%
barrioXdelito
# Out:
# TipoDelito             Name  Accidente Vehicular  Agresión  Drogas  Extorsión  \
# 0              Abel Gilbert                  2.0       2.0     NaN        NaN
# 1                  Alborada                  1.0       NaN     NaN        NaN
# 2                 Atarazana                  3.0       NaN     NaN        NaN
# 3           Balerio Estacio                  NaN       2.0     NaN        NaN
# 4              Barrio Lindo                  5.0       1.0     NaN        NaN
# ..                      ...                  ...       ...     ...        ...
# 71                   Sopeña                  1.0       1.0     NaN        NaN
# 72                  Urdenor                  3.0       NaN     NaN        NaN
# 73                   Urdesa                  4.0       3.0     NaN        NaN
# 74                 Valdivia                  1.0       NaN     NaN        NaN
# 75                 Vergeles                  NaN       NaN     NaN        NaN
#
# TipoDelito  Fraude  Homicidio  Incendio  Robo  Secuestro  Vandalismo
# 0              NaN        4.0       NaN   9.0        NaN         NaN
# 1              NaN        2.0       NaN   2.0        NaN         NaN
# 2              NaN        NaN       NaN   NaN        NaN         NaN
# 3              NaN        2.0       NaN   NaN        NaN         NaN
# 4              NaN        NaN       NaN   1.0        NaN         NaN
# ..             ...        ...       ...   ...        ...         ...
# 71             NaN        NaN       NaN   NaN        NaN         NaN
# 72             NaN        1.0       NaN   NaN        NaN         NaN
# 73             NaN        1.0       NaN   8.0        NaN         1.0
# 74             NaN        NaN       NaN   NaN        NaN         NaN
# 75             NaN        NaN       NaN   2.0        NaN         NaN
#
# [76 rows x 11 columns]

# %%
barrioXdelito = barrioXdelito.fillna(0)

# %%
barrioXdelito.to_csv("../output/delito-por-barrio.csv", index=False)
